# %% [markdown]
# <a href="https://colab.research.google.com/github/psrana/Machine-Learning-using-PyCaret/blob/main/03_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ---
# # **1. Clustering - Part 1 (Kmean Clustering)**
# ---
# ### **1.1 Get the list of datasets available in pycaret (55)**

# %% [markdown]
#   ---
# ### **1.4 "Parameter setting"  for clustering model**
# ##### **Train/Test division, applying data pre-processing** {Sampling, Normalization, Transformation, PCA, Handaling of Outliers, Feature Selection}
# ---

# %%
from pycaret.clustering import *
import pandas as pd

jewelleryDataSet = pd.read_csv('/kaggle/input/eobhrfb/Mall_Customers.csv')
kMeanClusteringParameters = setup(jewelleryDataSet)
# Re-run the code if any error occur
# Out:
# <style type="text/css">
# #T_0c28f_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0c28f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c28f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0c28f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c28f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c28f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0c28f_row0_col1" class="data row0 col1" >3189</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c28f_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_0c28f_row1_col1" class="data row1 col1" >(200, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c28f_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_0c28f_row2_col1" class="data row2 col1" >(200, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c28f_row3_col0" class="data row3 col0" >Ordinal features</td>
#       <td id="T_0c28f_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c28f_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_0c28f_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c28f_row5_col0" class="data row5 col0" >Categorical features</td>
#       <td id="T_0c28f_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c28f_row6_col0" class="data row6 col0" >Preprocess</td>
#       <td id="T_0c28f_row6_col1" class="data row6 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c28f_row7_col0" class="data row7 col0" >Imputation type</td>
#       <td id="T_0c28f_row7_col1" class="data row7 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c28f_row8_col0" class="data row8 col0" >Numeric imputation</td>
#       <td id="T_0c28f_row8_col1" class="data row8 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c28f_row9_col0" class="data row9 col0" >Categorical imputation</td>
#       <td id="T_0c28f_row9_col1" class="data row9 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0c28f_row10_col0" class="data row10 col0" >Maximum one-hot encoding</td>
#       <td id="T_0c28f_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0c28f_row11_col0" class="data row11 col0" >Encoding method</td>
#       <td id="T_0c28f_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0c28f_row12_col0" class="data row12 col0" >CPU Jobs</td>
#       <td id="T_0c28f_row12_col1" class="data row12 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0c28f_row13_col0" class="data row13 col0" >Use GPU</td>
#       <td id="T_0c28f_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0c28f_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_0c28f_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0c28f_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_0c28f_row15_col1" class="data row15 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0c28f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0c28f_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_0c28f_row16_col1" class="data row16 col1" >f928</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ### **1.5 Building "KMean" clustering model**
# ---

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a682f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a682f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a682f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a682f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a682f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a682f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a682f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a682f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a682f_row0_col0" class="data row0 col0" >0.4225</td>
#       <td id="T_a682f_row0_col1" class="data row0 col1" >260.8338</td>
#       <td id="T_a682f_row0_col2" class="data row0 col2" >0.8582</td>
#       <td id="T_a682f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a682f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a682f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **1.6 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#        Cluster
# 0    Cluster 3
# 1    Cluster 3
# 2    Cluster 3
# 3    Cluster 3
# 4    Cluster 3
# ..         ...
# 195  Cluster 1
# 196  Cluster 2
# 197  Cluster 1
# 198  Cluster 2
# 199  Cluster 1
#
# [200 rows x 6 columns]

# %% [markdown]
# ---
# ### **1.7 Clustering in "Three line of code"**
# ---

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(jewelleryDataSet, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_208b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_208b1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_208b1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_208b1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_208b1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_208b1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_208b1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_208b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_208b1_row0_col0" class="data row0 col0" >0.4225</td>
#       <td id="T_208b1_row0_col1" class="data row0 col1" >260.8338</td>
#       <td id="T_208b1_row0_col2" class="data row0 col2" >0.8582</td>
#       <td id="T_208b1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_208b1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_208b1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#        Cluster
# 0    Cluster 1
# 1    Cluster 1
# 2    Cluster 1
# 3    Cluster 1
# 4    Cluster 1
# ..         ...
# 195  Cluster 2
# 196  Cluster 3
# 197  Cluster 2
# 198  Cluster 3
# 199  Cluster 2
#
# [200 rows x 6 columns]

# %% [markdown]
# ---
# ### **1.8 "Saving" the result**
# ---

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# ### **1.9 Download the "result file" to user local system**
# ---

# %% [markdown]
# ---
# # **2. Clustering: Saving and Loading the Model**
# ---
# ### **2.1 Save the "trained model"**
# ---

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **2.2 Download the "trained model**
# ---

# %%
from google.colab import files
#files.download('kMeanClusteringModelFile.pkl')      # Uncomment this line

# %% [markdown]
# ---
# ### **2.3 Load the model**
# ---
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine

# %%
KMeanClusteringModel1 = load_model('kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **2.4 Upload and Load the trained model to "Colab Environment"**
# ---
# ##### **Upload the trained model**

# %%
from google.colab import files
#files.upload()                     # Uncomment this line

# %% [markdown]
# ##### **Load the trained model**

# %% [markdown]
# ---
# # **3. Clustering: Cluster the new dataset (Unseen Data)**
# ---
# ### **3.1 Select some data or upload user dataset file**

# %%
# Select top 10 rows
newData = pd.read_csv('/kaggle/input/eobhrfb/Mall_Customers.csv')

# %% [markdown]
# ---
# ### **3.2 Make prediction on the new dataset (Unseen Data)**
# ---

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# Out:
#      CustomerID  Genre   Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1.0    1.0  19.0                15.0                    39.0
# 1           2.0    1.0  21.0                15.0                    81.0
# 2           3.0    0.0  20.0                16.0                     6.0
# 3           4.0    0.0  23.0                16.0                    77.0
# 4           5.0    0.0  31.0                17.0                    40.0
# ..          ...    ...   ...                 ...                     ...
# 195       196.0    0.0  35.0               120.0                    79.0
# 196       197.0    0.0  45.0               126.0                    28.0
# 197       198.0    1.0  32.0               126.0                    74.0
# 198       199.0    1.0  32.0               137.0                    18.0
# 199       200.0    1.0  30.0               137.0                    83.0
#
#        Cluster
# 0    Cluster 1
# 1    Cluster 1
# 2    Cluster 1
# 3    Cluster 1
# 4    Cluster 1
# ..         ...
# 195  Cluster 2
# 196  Cluster 3
# 197  Cluster 2
# 198  Cluster 3
# 199  Cluster 2
#
# [200 rows x 6 columns]

# %% [markdown]
# ---
# ### **3.3 Save the prediction result to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# # **4. Clustering: Ploting the Cluster**
# ---
# ```
# - Cluster PCA Plot (2d)          'cluster'
# - Cluster TSnE (3d)              'tsne'
# - Elbow Plot                     'elbow'
# - Silhouette Plot                'silhouette'
# - Distance Plot                  'distance'
# - Distribution Plot              'distribution'
# ```

# %% [markdown]
# ---
# ### **4.1 Evaluate Cluster Model**
# ---

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **4.2 2D-plot for Cluster**
# ---

# %%
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e371b795-5b98-4b2e-8dfd-0f6f7feba258" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
0.6561855,-0.515131,0.20846762,0.2835765,-0.46854496,0.83457094,0.67106295,0.81582004,0.5429017,0.89912206,-0.17122586,-0.67230076,0.998315,0.9981947,0.60814804,0.76510733,0.2400954,0.82534826,0.26440132,0.9432107,-0.35964614,0.5166313,0.40277383,0.7405841,0.75293404,-0.518439,0.45431152,-0.6959156,-0.019947719,0.61782473,-0.0806695,0.90490097,-0.5366931,-0.4784976,-0.39831313,0.32718003,-0.69885606,0.7818103,0.7777929,1.0384226,0.64928216,0.878655,-0.28462642,0.26077715,-0.6707326,0.85581195,0.5127547,-0.20926024,0.59688395,-0.41606146,0.50312406,-0.5374938,0.048258856,0.89268094,-0.6977033],"type":"scatter3d"},{"customdata":[[1],[59],[27],[26],[25],[24],[23],[22],[21],[20],[18],[17],[16],[15],[28],[14],[12],[11],[10],[9],[8],[7],[6],[5],[4],[3],[2],[62],[13],[29],[19],[31],[57],[56],[55],[30],[53],[52],[51],[50],[49],[48],[47],[46],[45],[44],[54],[42],[32],[43],[34],[35],[36],[33],[38],[39],[40],[41],[37]],"hovertemplate":"Cluster=Cluster 1\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 1","marker":{"color":"#EF553B","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"Cluster 1" ...

# %% [markdown]
# ---
# ### **4.4 Elbow Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %% [markdown]
# ---
# ### **4.5 Silhouette Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'silhouette')

# %% [markdown]
# ---
# ### **4.6 Distribution Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <div>                            <div id="07e30b27-a619-411d-b638-e7ba5cb52201" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07e30b27-a619-411d-b638-e7ba5cb52201")) {                    Plotly.newPlot(                        "07e30b27-a619-411d-b638-e7ba5cb52201",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Cluster=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"Cluster 0","offsetgroup":"Cluster 0","orientation":"v","showlegend":true,"x":["Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[100,"Male",20,61,49],[90,"Female",50,58,46],[89,"Female",34,58,60],[88,"Female",22,57,55],[87,"Female",55,57,58],[86,"Male",48,54,46],[85,"Female",21,54,57],[84,"Female",46,54,44],[83,"Male",67,54,41],[82,"Male",38,54,55],[81,"Male",57,54,51],[80,"Female",49,54,42],[79,"Female",23,54,52],[78,"Male",40,54,48],[77,"Female",45,54,53],[76,"Male",26,54,54],[75,"Male",59,54,47],[74,"Female",60,50,56],[73,"Female",60,50,49],[72,"Female",47,49,42],[71,"Male",70,49,55],[70,"Female",32,48,47],[69,"Male",19,48,59],[58,"Male",69,44,46],[68,"Female",68,48,48],[60,"Male",53,46,46],[61,"Male",70,46,56],[67,"Female",43,48,50],[63,"Female",67,47,52],[64,"Female",54,47,59],[91,"Female",68,59,55],[92,"Male",18,59,41],[93,"Male",48,60,49],[94,"Female",40,60,40],[127,"Male",43,71,35],[125,"Female",23,70,29],[123,"Female",40,69,58],[122,"Female",38,67,40],[121,"Male",27,67,56],[120,"Female",50,67,57],[119,"Female",51,67,43],[118,"Female",49,65,59],[117,"Female",63,65,43],[116,"Female",19,65,50],[115,"Female",18,65,48],[114,"Male",19,64,46],[113,"Female",38,64,42],[112,"Female",19,63,54],[65,"Male",63,48,51],[111,"Male",65,63,52],[109,"Male",68,63,43],[108,"Male",54,63,46],[107,"Female",66,63,50],[106,"Female",21,62,42],[105,"Male",49,62,56],[104,"Male",26,62,55],[103,"Male",67,62,59],[102,"Female",49,62,48],[101,"Female",23,62,41],[99,"Male",48,61,42],[98,"Female",27,60,50],[97,"Female",47,60,47],[96,"Male",24,60,52],[95,"Female",32,60,42],[110,"Male",66,63,48],[66,"Male",18,48,59]],"hovertemplate":"Cluster=%{x}\u003cbr\u003eCustomerID=%{customdata[0]}\u003cbr\u003eGenre=%{customdata[1]}\u003cbr\u003eAge=%{customdata[2]}\u003cbr\u003eAnnual Income (k$)=%{customdata[3]}\u003cbr\u003eSpending Score (1-100)=%{customdata[4]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa"},"name":"Cluster 0","notched":true,"offsetgroup":"Cluster 0","showlegend":false,"x":["Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0 ...

# %% [markdown]
# ---
# ### **4.7 Distance Plot**
# ---

# %%
# plot_model(KMeanClusteringModel, plot = 'distance') # Rerun the code

# %% [markdown]
# ---
# # **5. Compelete Code for Clustering (KMean)**
# ---
# ### **5.1 For Cluster = 3, 4, 5, 6**

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
setup(data = jewelleryDataSet, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_67a47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67a47_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_67a47_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_67a47_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_67a47_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_67a47_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_67a47_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67a47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67a47_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_67a47_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_67a47_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_67a47_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_67a47_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_67a47_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_29cd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29cd1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29cd1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29cd1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29cd1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29cd1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29cd1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29cd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29cd1_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_29cd1_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_29cd1_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_29cd1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_29cd1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_29cd1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_546bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_546bc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_546bc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_546bc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_546bc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_546bc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_546bc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_546bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_546bc_row0_col0" class="data row0 col0" >0.6777</td>
#       <td id="T_546bc_row0_col1" class="data row0 col1" >4685.1995</td>
#       <td id="T_546bc_row0_col2" class="data row0 col2" >0.4596</td>
#       <td id="T_546bc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_546bc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_546bc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_346f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_346f4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_346f4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_346f4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_346f4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_346f4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_346f4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_346f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_346f4_row0_col0" class="data row0 col0" >0.6063</td>
#       <td id="T_346f4_row0_col1" class="data row0 col1" >4780.1767</td>
#       <td id="T_346f4_row0_col2" class="data row0 col2" >0.5414</td>
#       <td id="T_346f4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_346f4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_346f4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **5.2 Other Clustering Algorithms**
# ---
# ```
# - K-Means clustering                 'kmeans'
# - Affinity Propagation               'ap'
# - Mean shift clustering              'meanshift'
# - Spectral Clustering                'sc'
# - Agglomerative Clustering           'hclust'
# - Density-Based Spatial Clustering   'dbscan'
# - OPTICS Clustering                  'optics'
# - Birch Clustering                   'birch'
# - K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# # **6. Clustering: Apply "Data Preprocessing"**
# ---
# ### **Read the Dataset**

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

# %% [markdown]
# ---
# ### **6.1 Model Performance using "Normalization"**
# ---
# ### **6.1.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3622b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3622b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3622b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3622b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3622b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3622b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3622b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3622b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3622b_row0_col0" class="data row0 col0" >0.7581</td>
#       <td id="T_3622b_row0_col1" class="data row0 col1" >1611.2647</td>
#       <td id="T_3622b_row0_col2" class="data row0 col2" >0.3743</td>
#       <td id="T_3622b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3622b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3622b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2094d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2094d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2094d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2094d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2094d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2094d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2094d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2094d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2094d_row0_col0" class="data row0 col0" >0.6963</td>
#       <td id="T_2094d_row0_col1" class="data row0 col1" >1066.5812</td>
#       <td id="T_2094d_row0_col2" class="data row0 col2" >0.5258</td>
#       <td id="T_2094d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2094d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2094d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_57804">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57804_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_57804_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_57804_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_57804_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_57804_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_57804_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57804_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57804_row0_col0" class="data row0 col0" >0.7581</td>
#       <td id="T_57804_row0_col1" class="data row0 col1" >1611.2647</td>
#       <td id="T_57804_row0_col2" class="data row0 col2" >0.3743</td>
#       <td id="T_57804_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_57804_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_57804_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_bb63a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb63a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bb63a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bb63a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bb63a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bb63a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bb63a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb63a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb63a_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_bb63a_row0_col1" class="data row0 col1" >3671.3580</td>
#       <td id="T_bb63a_row0_col2" class="data row0 col2" >0.2762</td>
#       <td id="T_bb63a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bb63a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bb63a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_2f232">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f232_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2f232_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2f232_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2f232_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2f232_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2f232_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f232_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f232_row0_col0" class="data row0 col0" >0.6317</td>
#       <td id="T_2f232_row0_col1" class="data row0 col1" >3195.9085</td>
#       <td id="T_2f232_row0_col2" class="data row0 col2" >0.7159</td>
#       <td id="T_2f232_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2f232_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2f232_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.3 3D Plot for Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters = 5)
plot_model(x, plot = 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_10ae8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10ae8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_10ae8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_10ae8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_10ae8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_10ae8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_10ae8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10ae8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10ae8_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_10ae8_row0_col1" class="data row0 col1" >3671.3580</td>
#       <td id="T_10ae8_row0_col2" class="data row0 col2" >0.2762</td>
#       <td id="T_10ae8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T
u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 1","marker":{"color":"#EF553B","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"Cluster 1","scene":"scene","showlegend":true,"x":[-15.563024,-14.815274,-14.989135,-11.897558,-10.840683,-12.707095,-11.961058,-13.054322,-11.53129,-13.117543,-14.180186,-11.92885,-10.525709,-9.276799,-12.0945425,-11.741454,-15.954717,-13.599077,-14.137086,-17.235073,-10.34294,- ...

# %% [markdown]
# ---
# ### **6.2 Model Performance using "Transformation"**
# ---
#
# ### **6.2.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3806e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3806e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3806e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3806e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3806e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3806e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3806e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3806e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3806e_row0_col0" class="data row0 col0" >0.7809</td>
#       <td id="T_3806e_row0_col1" class="data row0 col1" >3519.5778</td>
#       <td id="T_3806e_row0_col2" class="data row0 col2" >0.3135</td>
#       <td id="T_3806e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3806e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3806e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.2.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6a6b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a6b4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6a6b4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6a6b4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6a6b4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6a6b4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6a6b4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a6b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a6b4_row0_col0" class="data row0 col0" >0.7383</td>
#       <td id="T_6a6b4_row0_col1" class="data row0 col1" >1843.8285</td>
#       <td id="T_6a6b4_row0_col2" class="data row0 col2" >0.3816</td>
#       <td id="T_6a6b4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6a6b4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6a6b4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_3937d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3937d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3937d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3937d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3937d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3937d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3937d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3937d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3937d_row0_col0" class="data row0 col0" >0.7809</td>
#       <td id="T_3937d_row0_col1" class="data row0 col1" >3519.5778</td>
#       <td id="T_3937d_row0_col2" class="data row0 col2" >0.3135</td>
#       <td id="T_3937d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3937d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3937d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_74a91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74a91_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_74a91_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_74a91_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_74a91_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_74a91_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_74a91_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74a91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74a91_row0_col0" class="data row0 col0" >0.6558</td>
#       <td id="T_74a91_row0_col1" class="data row0 col1" >3115.4026</td>
#       <td id="T_74a91_row0_col2" class="data row0 col2" >0.5886</td>
#       <td id="T_74a91_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_74a91_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_74a91_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_d63a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d63a3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d63a3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d63a3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d63a3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d63a3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d63a3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d63a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d63a3_row0_col0" class="data row0 col0" >0.5319</td>
#       <td id="T_d63a3_row0_col1" class="data row0 col1" >2972.9943</td>
#       <td id="T_d63a3_row0_col2" class="data row0 col2" >0.7775</td>
#       <td id="T_d63a3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d63a3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d63a3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.3 Model Performance using "PCA"**
# ---
# ### **6.3.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ad9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ad9f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1ad9f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1ad9f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1ad9f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1ad9f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1ad9f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ad9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ad9f_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_1ad9f_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_1ad9f_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_1ad9f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1ad9f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1ad9f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.3.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_217ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_217ab_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_217ab_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_217ab_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_217ab_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_217ab_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_217ab_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_217ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_217ab_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_217ab_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_217ab_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_217ab_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_217ab_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_217ab_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f2729">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2729_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f2729_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f2729_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f2729_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f2729_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f2729_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2729_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2729_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_f2729_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_f2729_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_f2729_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f2729_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f2729_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_a2540">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2540_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a2540_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a2540_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a2540_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a2540_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a2540_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2540_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2540_row0_col0" class="data row0 col0" >0.6777</td>
#       <td id="T_a2540_row0_col1" class="data row0 col1" >4685.1995</td>
#       <td id="T_a2540_row0_col2" class="data row0 col2" >0.4596</td>
#       <td id="T_a2540_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a2540_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a2540_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_49775">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49775_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_49775_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_49775_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_49775_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_49775_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_49775_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49775_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49775_row0_col0" class="data row0 col0" >0.5778</td>
#       <td id="T_49775_row0_col1" class="data row0 col1" >4806.0041</td>
#       <td id="T_49775_row0_col2" class="data row0 col2" >0.5735</td>
#       <td id="T_49775_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_49775_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_49775_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.4 Model Performance using "Transformation" + "Normalization"**
# ---
# ### **6.4.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4169f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4169f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4169f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4169f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4169f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4169f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4169f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4169f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4169f_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_4169f_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_4169f_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_4169f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4169f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4169f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.4.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a59f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a59f8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a59f8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a59f8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a59f8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a59f8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a59f8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a59f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a59f8_row0_col0" class="data row0 col0" >0.6912</td>
#       <td id="T_a59f8_row0_col1" class="data row0 col1" >1016.4677</td>
#       <td id="T_a59f8_row0_col2" class="data row0 col2" >0.5410</td>
#       <td id="T_a59f8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a59f8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a59f8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_4bd1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bd1d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4bd1d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4bd1d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4bd1d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4bd1d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4bd1d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bd1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bd1d_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_4bd1d_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_4bd1d_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_4bd1d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4bd1d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4bd1d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_de4c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de4c5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_de4c5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_de4c5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_de4c5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_de4c5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_de4c5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de4c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de4c5_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_de4c5_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_de4c5_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_de4c5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_de4c5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_de4c5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_3059b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3059b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3059b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3059b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3059b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3059b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3059b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3059b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3059b_row0_col0" class="data row0 col0" >0.6327</td>
#       <td id="T_3059b_row0_col1" class="data row0 col1" >3054.7820</td>
#       <td id="T_3059b_row0_col2" class="data row0 col2" >0.7246</td>
#       <td id="T_3059b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3059b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3059b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5 Model Performance using "Transformation" + "Normalization" + "PCA"**
# ---
# ### **6.5.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9319d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9319d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9319d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9319d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9319d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9319d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9319d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9319d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9319d_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_9319d_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_9319d_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_9319d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9319d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9319d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4c6dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c6dd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4c6dd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4c6dd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4c6dd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4c6dd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4c6dd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c6dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c6dd_row0_col0" class="data row0 col0" >0.6912</td>
#       <td id="T_4c6dd_row0_col1" class="data row0 col1" >1016.4677</td>
#       <td id="T_4c6dd_row0_col2" class="data row0 col2" >0.5410</td>
#       <td id="T_4c6dd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4c6dd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4c6dd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_4db28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4db28_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4db28_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4db28_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4db28_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4db28_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4db28_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4db28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4db28_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_4db28_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_4db28_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_4db28_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4db28_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4db28_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_f21e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f21e8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f21e8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f21e8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f21e8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f21e8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f21e8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f21e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f21e8_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_f21e8_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_f21e8_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_f21e8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f21e8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f21e8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_ce299">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce299_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ce299_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ce299_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ce299_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ce299_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ce299_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce299_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce299_row0_col0" class="data row0 col0" >0.6317</td>
#       <td id="T_ce299_row0_col1" class="data row0 col1" >3051.9404</td>
#       <td id="T_ce299_row0_col2" class="data row0 col2" >0.7363</td>
#       <td id="T_ce299_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ce299_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ce299_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

# %% [markdown]
# ---
# # **7. Other Clustering Techniques**
# ---
# ```
# K-Means clustering                 'kmeans'
# Affinity Propagation               'ap'
# Mean shift clustering              'meanshift'
# Spectral Clustering                'sc'
# Agglomerative Clustering           'hclust'
# Density-Based Spatial Clustering   'dbscan'
# OPTICS Clustering                  'optics'
# Birch Clustering                   'birch'
# K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# ### **7.1 Buildign Agglomerative (Hierarchical) clustering model**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

setup(data = jewelleryDataSet, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_de6c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de6c9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_de6c9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_de6c9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_de6c9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_de6c9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_de6c9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de6c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de6c9_row0_col0" class="data row0 col0" >0.7060</td>
#       <td id="T_de6c9_row0_col1" class="data row0 col1" >4827.2243</td>
#       <td id="T_de6c9_row0_col2" class="data row0 col2" >0.4339</td>
#       <td id="T_de6c9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_de6c9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_de6c9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = jewelleryDataSet, transformation = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e039b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e039b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e039b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e039b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e039b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e039b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e039b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e039b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e039b_row0_col0" class="data row0 col0" >0.7383</td>
#       <td id="T_e039b_row0_col1" class="data row0 col1" >1843.8285</td>
#       <td id="T_e039b_row0_col2" class="data row0 col2" >0.3816</td>
#       <td id="T_e039b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e039b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e039b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_8c4a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c4a1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8c4a1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8c4a1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8c4a1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8c4a1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8c4a1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c4a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c4a1_row0_col0" class="data row0 col0" >0.7809</td>
#       <td id="T_8c4a1_row0_col1" class="data row0 col1" >3519.5778</td>
#       <td id="T_8c4a1_row0_col2" class="data row0 col2" >0.3135</td>
#       <td id="T_8c4a1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8c4a1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8c4a1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_85639">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85639_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_85639_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_85639_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_85639_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_85639_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_85639_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85639_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85639_row0_col0" class="data row0 col0" >0.6506</td>
#       <td id="T_85639_row0_col1" class="data row0 col1" >3043.7651</td>
#       <td id="T_85639_row0_col2" class="data row0 col2" >0.5975</td>
#       <td id="T_85639_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_85639_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_85639_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_be631">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be631_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_be631_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_be631_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_be631_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_be631_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_be631_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be631_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be631_row0_col0" class="data row0 col0" >0.5139</td>
#       <td id="T_be631_row0_col1" class="data row0 col1" >2818.2489</td>
#       <td id="T_be631_row0_col2" class="data row0 col2" >0.7798</td>
#       <td id="T_be631_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_be631_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_be631_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.1.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
hierarchicalModel = create_model('hclust', num_clusters=3)
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_efa60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efa60_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_efa60_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_efa60_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_efa60_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_efa60_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_efa60_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efa60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efa60_row0_col0" class="data row0 col0" >0.7391</td>
#       <td id="T_efa60_row0_col1" class="data row0 col1" >3542.6251</td>
#       <td id="T_efa60_row0_col2" class="data row0 col2" >0.3407</td>
#       <td id="T_efa60_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_efa60_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_efa60_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 0
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff687">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff687_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ff687_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ff687_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ff687_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ff687_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ff687_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff687_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff687_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_ff687_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_ff687_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_ff687_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ff687_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ff687_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.1.2 Evaluate Agglomerative (Hierarchical) Clustering**
# ---

# %%
evaluate_model(hierarchicalModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **7.2 Density-Based Spatial Clustering**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

setup(data = jewelleryDataSet, verbose=False)
dbscanModel = create_model('dbscan')
# Out:
# <style type="text/css">
# </style>
# <table id="T_44dbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44dbe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_44dbe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_44dbe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_44dbe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_44dbe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_44dbe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44dbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44dbe_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_44dbe_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_44dbe_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_44dbe_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_44dbe_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_44dbe_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.2.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
dbscanModelPrediction = assign_model(dbscanModel)
dbscanModelPrediction

# Noisy samples are given the label -1 i.e. 'Cluster -1'
# Out:
#      Age  Income  SpendingScore       Savings     Cluster
# 0     58   77769       0.791329   6559.830078  Cluster -1
# 1     59   81799       0.791082   5417.661621  Cluster -1
# 2     62   74751       0.702657   9258.993164  Cluster -1
# 3     59   74373       0.765680   7346.334473  Cluster -1
# 4     87   17760       0.348778  16869.507812  Cluster -1
# ..   ...     ...            ...           ...         ...
# 500   28  101206       0.387441  14936.775391  Cluster -1
# 501   93   19934       0.203140  17969.693359  Cluster -1
# 502   90   35297       0.355149  16091.402344  Cluster -1
# 503   91   20681       0.354679  18401.087891  Cluster -1
# 504   89   30267       0.289310  14386.351562  Cluster -1
#
# [505 rows x 5 columns]

# %% [markdown]
# ### **Key Points**

# %% [markdown]
# - num_clusters not required for some of the clustering Alorithms (Affinity Propagation ('ap'), Mean shift
#   clustering ('meanshift'), Density-Based Spatial Clustering ('dbscan') and OPTICS Clustering ('optics')).
# - num_clusters param for these models are automatically determined.
#
# - When fit doesn't converge in Affinity Propagation ('ap') model, all datapoints are labelled as -1.
#
# - Noisy samples are given the label -1, when using Density-Based Spatial  ('dbscan') or OPTICS Clustering ('optics').
#
# - OPTICS ('optics') clustering may take longer training times on large datasets.

# %% [markdown]
# ---
# # **8. Deploy the model on AWS**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html#pycaret.clustering.deploy_model">Click Here</a>**
